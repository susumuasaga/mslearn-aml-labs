# %% [markdown]
# # Creating an Azure Machine Learning Pipeline
#
# You can perform the various steps required to ingest data, train a model, and register the model individually by using the Azure ML SDK to run script-based experiments. However, in an enterprise environment it is common to encapsulate the sequence of discrete steps required to build a machine learning solution into a *pipeline* that can be run on one or more compute targets, either on-demand by a user, from an automated build process, or on a schedule.
#
# In this lab, you'll bring together all of these elements to create a simple pipeline that trains and registers a model.
#
# ## Connect to Your Workspace
#
# The first thing you need to do is to connect to your workspace using the Azure ML SDK.
#
# > **Note**: If the authenticated session with your Azure subscription has expired since you completed the previous exercise, you'll be prompted to reauthenticate.

# %%
from azureml import core

ws = core.Workspace.from_config()
print(f'Ready to use Azure ML {core.VERSION} to work with {ws.name}')
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (portalocker 2.0.0 (/anaconda/envs/azureml_py36/lib/python3.6/site-packages), Requirement.parse('portalocker~=1.0'), {'msal-extensions'}).
# Ready to use Azure ML 1.11.0 to work with workspace

# %% [markdown]
# ## Prepare the Training Data
#
# You can use local data files to train a model, but when running training workloads automatically on cloud-based compute, it makes more sense to store the data centrally in the cloud and ingest it into the training script wherever it happens to be running.
#
# In this lab, you'll upload the training data to a *datastore* and define a *dataset* that can be used to access the data from a training script. For simplicity, you'll upload the data to the default datastore for your Azure Machine Learning workspace - this is an Azure Storage blob container that was created when you provisioned the workspace. In a real solution, you'd likely register a datastore that references the cloud location where you typically store your data. You'll then create a *tabular* dataset that references the CSV files you uploaded.

# %%
default_ds = ws.get_default_datastore()

# %% [markdown]
# ## Prepare a Compute Environment for the Pipeline Steps
#
# The pipeline will eventually be published and run on-demand, so it needs a compute environment in which to run. In this exercise, you'll use the same compute for both steps, but it's important to realize that each step is run independently; so you could specify different compute contexts for each step if appropriate.
#
# First, you need a compute target. In this case, you create an Azure Machine Learning compute cluster in your workspace (or use an existing one if you have created it previously).
#
# > **Important**: Change *your-compute-cluster* to the unique name for your compute cluster in the code below before running it!

# %%
from azureml.core import compute

cluster_name = "susumu-cluster"

pipeline_cluster = compute.ComputeTarget(workspace=ws, name=cluster_name)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# The compute will require a Python environment with the necessary package dependencies installed, so we'll create a run configuration.

# %%
from azureml.core import conda_dependencies
from azureml.core import runconfig

diabetes_env = core.Environment('diabetes-pipeline-env')
diabetes_env.python.user_managed_dependencies = False
diabetes_env.docker.enabled = True

diabetes_packages = conda_dependencies.CondaDependencies.create(
    conda_packages=['scikit-learn','pandas'],
    pip_packages=['azureml-defaults','azureml-dataprep[pandas]']
)

diabetes_env.python.conda_dependencies = diabetes_packages

diabetes_env.register(workspace=ws)
registered_env = core.Environment.get(ws, 'diabetes-pipeline-env')

pipeline_run_config = runconfig.RunConfiguration()

pipeline_run_config.target = pipeline_cluster

pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and Run a Pipeline
#
# Now you're ready to define and run the pipeline.
#
# First you need to define the steps for the pipeline, and any data references that need to passed between them. In this case, the first step must write the model to a folder that can be read from by the second step. Since the steps will be run on remote compute (and in fact, could each be run on different compute), the folder path must be passed as a data reference to a location in a datastore within the workspace. The **PipelineData** object is a special kind of data reference that is used to pass data from the output of one pipeline step to the input of another, creating a dependency between them. You'll create one and use it as the output for the first step and the input for the second step. Note that you also need to pass it as a script argument so your code can access the datastore location referenced by the data reference.

# %%
from azureml import pipeline
from azureml.pipeline import steps
from azureml.train import estimator

diabetes_ds = ws.datasets.get('diabetes dataset')

model_folder = pipeline.core.PipelineData(
    "model_folder", datastore=ws.get_default_datastore(),
)

experiment_folder = 'diabetes-pipeline'
config = estimator.Estimator(
    source_directory=experiment_folder,
    compute_target = pipeline_cluster,
    environment_definition=pipeline_run_config.environment,
    entry_script='train_diabetes.py'
)

train_step = steps.EstimatorStep(
    name='Train Model',
    estimator=config, 
    estimator_entry_script_arguments=['--output_folder', model_folder],
    inputs=[diabetes_ds.as_named_input('diabetes_train')],
    outputs=[model_folder],
    compute_target = pipeline_cluster,
    allow_reuse = True,
)

register_step = steps.PythonScriptStep(
    name='Register Model',
    source_directory= experiment_folder,
    script_name='register_diabetes.py',
    arguments = ['--model_folder', model_folder],
    inputs=[model_folder],
    compute_target = pipeline_cluster,
    runconfig = pipeline_run_config,
    allow_reuse = True,
)

print('Pipeline steps defined')
# Out:
# Pipeline steps defined

# %% [markdown]
# OK, now you're ready to build the pipeline from the steps you've defined and run it as an experiment.
#
# > **Note**: This may take a while. The training cluster must be started and configured with the Python environment before the scripts can be run. Now might be a good time to take a coffee break!

# %%
from azureml import widgets

pipeline_steps = [train_step, register_step]
p = pipeline.core.Pipeline(workspace=ws, steps=pipeline_steps)
print('Pipeline is built.')

experiment = core.Experiment(workspace=ws, name='diabetes-training-pipeline')
pipeline_run = experiment.submit(p, regenerate_outputs=True)
print('Pipeline submitted for execution.')

widgets.RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()
# Out:
# Pipeline is built.
# Created step Train Model [b81a8eb0][6711c624-86ad-47c9-a588-76ff083bb609], (This step will run and generate new outputs)Created step Register Model [5f97c679][ff75aeb0-1b05-4689-8937-b7dbf170db99], (This step will run and generate new outputs)
#
# Submitted PipelineRun 2c0aacff-454a-4c60-9207-1c7b1033168c
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/2c0aacff-454a-4c60-9207-1c7b1033168c?wsid=/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourcegroups/resources/workspaces/workspace
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 2c0aacff-454a-4c60-9207-1c7b1033168c
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/2c0aacff-454a-4c60-9207-1c7b1033168c?wsid=/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourcegroups/resources/workspaces/workspace
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: a5614e8d-76f9-4d63-85db-51966e5694fa
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/a5614e8d-76f9-4d63-85db-51966e5694fa?wsid=/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourcegroups/resources/workspaces/workspace
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/08/15 01:48:53 Downloading source code...
# 2020/08/15 01:48:54 Finished downloading source code
# 2020/08/15 01:48:54 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/08/15 01:48:55 Successfully set up Docker network: acb_default_network
# 2020/08/15 01:48:55 Setting up Docker configuration...
# 2020/08/15 01:48:55 Successfully set up Docker configuration
# 2020/08/15 01:48:55 Logging in to registry: 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io
# 2020/08/15 01:48:57 Successfully logged into 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io
# 2020/08/15 01:48:57 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/08/15 01:48:57 Scanning for dependencies...
# 2020/08/15 01:48:57 Successfully scanned dependencies
# 2020/08/15 01:48:57 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1@sha256:6446903197a22de6711cbbf07f047b351d84d3ec9f3cab62f6312433461e5608
# sha256:6446903197a22de6711cbbf07f047b351d84d3ec9f3cab62f6312433461e5608: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 6aa38bd67045: Already exists
# 981ae4862c05: Already exists
# 5bad8949dcb1: Already exists
# ca9461589e70: Already exists
# 98d7f5a52dc7: Pulling fs layer
# 55bd0fd3d326: Pulling fs layer
# c701d81a8c64: Pulling fs layer
# 377536e3f3d3: Pulling fs layer
# be7af55ccd20: Pulling fs layer
# 527ddc9414f3: Pulling fs layer
# 67e3aa572370: Pulling fs layer
# 41d293c79c2d: Pulling fs layer
# 377536e3f3d3: Waiting
# be7af55ccd20: Waiting
# 527ddc9414f3: Waiting
# 67e3aa572370: Waiting
# 41d293c79c2d: Waiting
# 55bd0fd3d326: Verifying Checksum
# 55bd0fd3d326: Download complete
# c701d81a8c64: Verifying Checksum
# c701d81a8c64: Download complete
# 98d7f5a52dc7: Verifying Checksum
# 98d7f5a52dc7: Download complete
# 377536e3f3d3: Verifying Checksum
# 377536e3f3d3: Download complete
# 527ddc9414f3: Verifying Checksum
# 527ddc9414f3: Download complete
# be7af55ccd20: Verifying Checksum
# be7af55ccd20: Download complete
# 67e3aa572370: Verifying Checksum
# 67e3aa572370: Download complete
# 41d293c79c2d: Verifying Checksum
# 41d293c79c2d: Download complete
# 98d7f5a52dc7: Pull complete
# 55bd0fd3d326: Pull complete
# c701d81a8c64: Pull complete
# 377536e3f3d3: Pull complete
# be7af55ccd20: Pull complete
# 527ddc9414f3: Pull complete
# 67e3aa572370: Pull complete
# 41d293c79c2d: Pull complete
# Digest: sha256:6446903197a22de6711cbbf07f047b351d84d3ec9f3cab62f6312433461e5608
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1@sha256:6446903197a22de6711cbbf07f047b351d84d3ec9f3cab62f6312433461e5608
#  ---> 6c431041858f
# Step 2/15 : USER root
#  ---> Running in ea2f414f385e
# Removing intermediate container ea2f414f385e
#  ---> a7c4a6f6895d
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 75c85a3313fd
# Removing intermediate container 75c85a3313fd
#  ---> a94cfd68c52f
# Step 4/15 : WORKDIR /
#  ---> Running in 6cb8a78cf152
# Removing intermediate container 6cb8a78cf152
#  ---> 73b85280b1c8
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 668b69de1191
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 89e2f3a9f54c
# Removing intermediate container 89e2f3a9f54c
#  ---> e9c85a1c14ac
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 7d3fb53880fc
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 532fecebc0c2
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | 6          |   7%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 3          |   3%
# mkl-2019.4           | 204.1 MB  | 7          |   7%
# mkl-2019.4           | 204.1 MB  | #1         |  12%
# mkl-2019.4           | 204.1 MB  | #6         |  16%
# mkl-2019.4           | 204.1 MB  | ##         |  20%
# mkl-2019.4           | 204.1 MB  | ##4        |  25%
# mkl-2019.4           | 204.1 MB  | ##9        |  29%
# mkl-2019.4           | 204.1 MB  | ###3       |  34%
# mkl-2019.4           | 204.1 MB  | ###8       |  38%
# mkl-2019.4           | 204.1 MB  | ####2      |  43%
# mkl-2019.4           | 204.1 MB  | ####7      |  47%
# mkl-2019.4           | 204.1 MB  | #####1     |  51%
# mkl-2019.4           | 204.1 MB  | #####5     |  56%
# mkl-2019.4           | 204.1 MB  | ######     |  60%
# mkl-2019.4           | 204.1 MB  | ######4    |  65%
# mkl-2019.4           | 204.1 MB  | ######9    |  69%
# mkl-2019.4           | 204.1 MB  | #######3   |  74%
# mkl-2019.4           | 204.1 MB  | #######8   |  78%
# mkl-2019.4           | 204.1 MB  | ########2  |  83%
# mkl-2019.4           | 204.1 MB  | ########7  |  87%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# pandas-1.1.0         | 10.5 MB   |            |   0%
# pandas-1.1.0         | 10.5 MB   | #####8     |  59%
# pandas-1.1.0         | 10.5 MB   | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######5    |  65%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# mkl_fft-1.1.0        | 159 KB    |            |   0%
# mkl_fft-1.1.0        | 159 KB    | ########## | 100%
#
# scikit-learn-0.23.1  | 6.9 MB    |            |   0%
# scikit-learn-0.23.1  | 6.9 MB    | ########4  |  85%
# scikit-learn-0.23.1  | 6.9 MB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# setuptools-49.2.1    | 944 KB    |            |   0%
# setuptools-49.2.1    | 944 KB    | ########## | 100%
#
# pip-20.2.2           | 2.0 MB    |            |   0%
# pip-20.2.2           | 2.0 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########3  |  83%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# scipy-1.5.0          | 18.6 MB   |            |   0%
# scipy-1.5.0          | 18.6 MB   | ###3       |  34%
# scipy-1.5.0          | 18.6 MB   | ########2  |  82%
# scipy-1.5.0          | 18.6 MB   | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# ca-certificates-2020 | 133 KB    |            |   0%
# ca-certificates-2020 | 133 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##4        |  24%
# python-3.6.2         | 27.0 MB   | #####5     |  56%
# python-3.6.2         | 27.0 MB   | ########4  |  85%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# joblib-0.16.0        | 210 KB    |            |   0%
# joblib-0.16.0        | 210 KB    | ########## | 100%
#
# intel-openmp-2020.1  | 940 KB    |            |   0%
# intel-openmp-2020.1  | 940 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.qaqoi8lv.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.11.0
#   Downloading azureml_defaults-1.11.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.0.5-py3-none-any.whl (28.1 MB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.11.0
#   Downloading azureml_dataset_runtime-1.11.0.post1-py3-none-any.whl (3.3 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-core~=1.11.0
#   Downloading azureml_core-1.11.0.post1-py3-none-any.whl (2.0 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting azureml-dataprep-native<15.0.0,>=14.2.1
#   Downloading azureml_dataprep_native-14.2.1-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.5.0-py3-none-any.whl (22 kB)
# Collecting pyarrow<1.0.0,>=0.17.0; extra == "pandas"
#   Downloading pyarrow-0.17.1-cp36-cp36m-manylinux2014_x86_64.whl (63.8 MB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.qaqoi8lv.requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.qaqoi8lv.requirements.txt (line 2)) (1.19.1)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/lib/python3.6/site-packages (from azureml-core~=1.11.0->azureml-defaults~=1.11.0->-r /azureml-environment-setup/condaenv.qaqoi8lv.requirements.txt (line 1)) (2.8.1)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-11.1.0-py2.py3-none-any.whl (547 kB)
# Collecting docker
#   Downloading docker-4.3.0-py2.py3-none-any.whl (145 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.2.0-py2.py3-none-any.whl (968 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.0-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.10-py2.py3-none-any.whl (127 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/lib/python3.6/site-packages (from azureml-core~=1.11.0->azureml-defaults~=1.11.0->-r /azureml-environment-setup/condaenv.qaqoi8lv.requirements.txt (line 1)) (2020.1)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.18-py2.py3-none-any.whl (84 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.11.0->-r /azureml-environment-setup/condaenv.qaqoi8lv.requirements.txt (line 1)) (1.15.0)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.4.0.tar.gz (15 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.8.0-py2.py3-none-any.whl (121 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.4.3-py2.py3-none-any.whl (49 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.7.0-py2.py3-none-any.whl (31 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.1-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.11.0->azureml-defaults~=1.11.0->-r /azureml-environment-setup/condaenv.qaqoi8lv.requirements.txt (line 1)) (2020.6.20)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff, dill
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=3be87f3b61aa6ae65749029a1a395257c1ff32cefb028b5b1cf001815b93bba8
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=9e6494caaf364856e06fe7490e195f4a15011f5f0f82ad82183f566911dac2b8
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-py3-none-any.whl size=13333 sha256=f60bfba3524920d5b684c0822fd845c4f3e2bba3bb600eef14918f769fc72033
#   Stored in directory: /root/.cache/pip/wheels/ba/2a/e1/6f7be2e2ea150e2486bff64fd6f0670f4f35f4c8f31c819fb8
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=0fe71552ded51dfa5b0d589d3da4d62bc6829f264489cf07a1a57c181c9c767b
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
# Successfully built json-logging-py fusepy liac-arff dill
# Installing collected packages: configparser, werkzeug, pyarrow, distro, dotnetcore2, azureml-dataprep-native, chardet, idna, urllib3, requests, azure-core, pycparser, cffi, cryptography, portalocker, PyJWT, msal, msal-extensions, azure-identity, cloudpickle, azureml-dataprep, fusepy, azureml-dataset-runtime, json-logging-py, contextlib2, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, pathspec, jeepney, SecretStorage, pyasn1, pyopenssl, ndg-httpsclient, azure-common, azure-mgmt-keyvault, azure-mgmt-authorization, azure-graphrbac, zipp, importlib-metadata, jsonpickle, azure-mgmt-storage, websocket-client, docker, azure-mgmt-resource, jmespath, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-containerregistry, backports.weakref, backports.tempfile, azureml-core, liac-arff, dill, azureml-model-management-sdk, applicationinsights, gunicorn, MarkupSafe, Jinja2, click, itsdangerous, flask, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.2.0 azure-mgmt-storage-11.1.0 azureml-core-1.11.0.post1 azureml-dataprep-2.0.5 azureml-dataprep-native-14.2.1 azureml-dataset-runtime-1.11.0.post1 azureml-defaults-1.11.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.1 chardet-3.0.4 click-7.1.2 cloudpickle-1.5.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.0 dill-0.3.2 distro-1.5.0 docker-4.3.0 dotnetcore2-2.1.14 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-1.7.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.4.0 msal-1.4.3 msal-extensions-0.1.3 msrest-0.6.18 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.1 pyarrow-0.17.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 urllib3-1.25.10 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.1.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.4
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 532fecebc0c2
#  ---> fec1adf0c4b5
# Step 9/15 : ENV PATH /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin:$PATH
#  ---> Running in 74a63e10b1b2
# Removing intermediate container 74a63e10b1b2
#  ---> 0a096347bd3d
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd
#  ---> Running in 237df52fd76d
# Removing intermediate container 237df52fd76d
#  ---> 8b4ae1abd686
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/lib:$LD_LIBRARY_PATH
#  ---> Running in 388c7a74af3c
# Removing intermediate container 388c7a74af3c
#  ---> 377953d24477
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> a366bdd3640b
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in a2d076e209e2
# Removing intermediate container a2d076e209e2
#  ---> a31b1051e9d6
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in f30839944c86
# Removing intermediate container f30839944c86
#  ---> 219a10f80d13
# Step 15/15 : CMD ["bash"]
#  ---> Running in e7225412ee33
# Removing intermediate container e7225412ee33
#  ---> e4bb75bacaea
# Successfully built e4bb75bacaea
# Successfully tagged 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559:latest
# 2020/08/15 01:52:40 Successfully executed container: acb_step_0
# 2020/08/15 01:52:40 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/08/15 01:52:40 Pushing image: 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559:latest, attempt 1
# The push refers to repository [9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559]
# f6e6de9d6d27: Preparing
# 572aed84903b: Preparing
# 37418fe9a49e: Preparing
# 614c90f3a4f8: Preparing
# 0c3cc7a276cf: Preparing
# 6d4734d2e752: Preparing
# ca4051980d49: Preparing
# 8445967f3cd7: Preparing
# 5b3957211d87: Preparing
# 5a68d248281a: Preparing
# 7bf666214bc3: Preparing
# 390b01cda284: Preparing
# 59fc75f21a74: Preparing
# 64c3df0bcd5e: Preparing
# 377c01c3f4e3: Preparing
# 968d3b985bf4: Preparing
# 631dfaad8559: Preparing
# d908d9ad6713: Preparing
# 6d4734d2e752: Waiting
# ca4051980d49: Waiting
# 8445967f3cd7: Waiting
# 5b3957211d87: Waiting
# 5a68d248281a: Waiting
# 7bf666214bc3: Waiting
# 390b01cda284: Waiting
# 59fc75f21a74: Waiting
# 64c3df0bcd5e: Waiting
# 377c01c3f4e3: Waiting
# 968d3b985bf4: Waiting
# 631dfaad8559: Waiting
# d908d9ad6713: Waiting
# 0c3cc7a276cf: Pushed
# f6e6de9d6d27: Pushed
# 614c90f3a4f8: Pushed
# 37418fe9a49e: Pushed
# 6d4734d2e752: Pushed
# 8445967f3cd7: Pushed
# ca4051980d49: Pushed
# 5b3957211d87: Pushed
# 59fc75f21a74: Pushed
# 5b3957211d87: Layer already exists
# f562e0739d27: Pushed
# 59fc75f21a74: Layer already exists
# 390b01cda284: Pushed
# 377c01c3f4e3: Pushed
# 5a68d248281a: Pushed
# 968d3b985bf4: Pushed
# 7bf666214bc3: Pushed
# 631dfaad8559: Pushed
# d908d9ad6713: Pushed
# 64c3df0bcd5e: Pushed
# f9ed2401dd07: Pushed
# latest: digest: sha256:e3dd50a3ac13403f60d67e39ba1815b34c737ac4b8d001430f3716b5078ad704 size: 4095
# 2020/08/15 02:05:23 Successfully pushed image: 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559:latest
# 2020/08/15 02:05:23 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 254.076560)
# 2020/08/15 02:05:23 Populating digests for step ID: acb_step_0...
# 2020/08/15 02:05:25 Successfully populated digests for step ID: acb_step_0
# 2020/08/15 02:05:25 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 134.179252)
# 2020/08/15 02:05:25 The following dependencies were found:
# 2020/08/15 02:05:25
# - image:
#     registry: 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io
#     repository: azureml/azureml_cff4c801596a77022874525482eac559
#     tag: latest
#     digest: sha256:e3dd50a3ac13403f60d67e39ba1815b34c737ac4b8d001430f3716b5078ad704
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200723.v1
#     digest: sha256:6446903197a22de6711cbbf07f047b351d84d3ec9f3cab62f6312433461e5608
#   git: {}
#
# Run ID: cq2 was successful after 6m43s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# ========================================================================================================================
# 2020-08-15T02:10:35Z Starting output-watcher...
# 2020-08-15T02:10:35Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-08-15T02:10:36Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-08-15T02:10:36Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_cff4c801596a77022874525482eac559
# 6aa38bd67045: Pulling fs layer
# 981ae4862c05: Pulling fs layer
# 5bad8949dcb1: Pulling fs layer
# ca9461589e70: Pulling fs layer
# 98d7f5a52dc7: Pulling fs layer
# 55bd0fd3d326: Pulling fs layer
# c701d81a8c64: Pulling fs layer
# 377536e3f3d3: Pulling fs layer
# be7af55ccd20: Pulling fs layer
# 527ddc9414f3: Pulling fs layer
# 67e3aa572370: Pulling fs layer
# 41d293c79c2d: Pulling fs layer
# 40003e40d7f2: Pulling fs layer
# 4177e3d77355: Pulling fs layer
# 1281d18e478b: Pulling fs layer
# 2f3745241d13: Pulling fs layer
# 752235faa860: Pulling fs layer
# ec3797bdaa3a: Pulling fs layer
# 527ddc9414f3: Waiting
# 67e3aa572370: Waiting
# 41d293c79c2d: Waiting
# 40003e40d7f2: Waiting
# 4177e3d77355: Waiting
# 1281d18e478b: Waiting
# 2f3745241d13: Waiting
# 752235faa860: Waiting
# ec3797bdaa3a: Waiting
# 55bd0fd3d326: Waiting
# c701d81a8c64: Waiting
# 377536e3f3d3: Waiting
# be7af55ccd20: Waiting
# ca9461589e70: Waiting
# 98d7f5a52dc7: Waiting
# 5bad8949dcb1: Verifying Checksum
# 5bad8949dcb1: Download complete
# 981ae4862c05: Verifying Checksum
# 981ae4862c05: Download complete
# ca9461589e70: Verifying Checksum
# ca9461589e70: Download complete
# 6aa38bd67045: Verifying Checksum
# 6aa38bd67045: Download complete
# 55bd0fd3d326: Verifying Checksum
# 55bd0fd3d326: Download complete
# c701d81a8c64: Verifying Checksum
# c701d81a8c64: Download complete
# 98d7f5a52dc7: Verifying Checksum
# 98d7f5a52dc7: Download complete
# 377536e3f3d3: Verifying Checksum
# 377536e3f3d3: Download complete
# 67e3aa572370: Verifying Checksum
# 67e3aa572370: Download complete
# 527ddc9414f3: Verifying Checksum
# 527ddc9414f3: Download complete
# 41d293c79c2d: Verifying Checksum
# 41d293c79c2d: Download complete
# 4177e3d77355: Verifying Checksum
# 4177e3d77355: Download complete
# be7af55ccd20: Verifying Checksum
# be7af55ccd20: Download complete
# 40003e40d7f2: Verifying Checksum
# 40003e40d7f2: Download complete
# 2f3745241d13: Verifying Checksum
# 2f3745241d13: Download complete
# 1281d18e478b: Verifying Checksum
# 1281d18e478b: Download complete
# ec3797bdaa3a: Verifying Checksum
# ec3797bdaa3a: Download complete
# 752235faa860: Verifying Checksum
# 752235faa860: Download complete
# 6aa38bd67045: Pull complete
# 981ae4862c05: Pull complete
# 5bad8949dcb1: Pull complete
# ca9461589e70: Pull complete
# 98d7f5a52dc7: Pull complete
# 55bd0fd3d326: Pull complete
# c701d81a8c64: Pull complete
# 377536e3f3d3: Pull complete
# be7af55ccd20: Pull complete
# 527ddc9414f3: Pull complete
# 67e3aa572370: Pull complete
# 41d293c79c2d: Pull complete
# 40003e40d7f2: Pull complete
# 4177e3d77355: Pull complete
# 1281d18e478b: Pull complete
# 2f3745241d13: Pull complete
# 752235faa860: Pull complete
# ec3797bdaa3a: Pull complete
# Digest: sha256:e3dd50a3ac13403f60d67e39ba1815b34c737ac4b8d001430f3716b5078ad704
# Status: Downloaded newer image for 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559:latest
# c9b3ac723464e3e78a2578fc94f69b1952a15d65a4e432078f911901bcbb655e
# 2020/08/15 02:12:17 Starting App Insight Logger for task:  containerSetup
# 2020/08/15 02:12:17 Version: 3.0.01307.0006 Branch: master Commit: a589a00
# 2020/08/15 02:12:17 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/15 02:12:17 sshd inside container not required for job, skipping setup.
# 2020/08/15 02:12:18 All App Insights Logs was send successfully
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# [2020-08-15T02:12:24.143437] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train_diabetes.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/mounts/workspaceblobstore/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/model_folder'])
# Starting the daemon thread to refresh tokens in background for process with pid = 111
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/mounts/workspaceblobstore/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa
# Preparing to call script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/mounts/workspaceblobstore/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/model_folder']
# After variable expansion, calling script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/mounts/workspaceblobstore/azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/model_folder']
#
# Script type = None
# Loading Data...
#
# Streaming azureml-logs/75_job_post-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-15T02:12:47.426995
# Starting job release. Current time:2020-08-15T02:12:48.345505
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 325
# [2020-08-15T02:12:48.364617] Entering context manager injector.
# Job release is complete. Current time:2020-08-15T02:12:48.880000
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': 'a5614e8d-76f9-4d63-85db-51966e5694fa', 'target': 'susumu-cluster', 'status': 'Completed', 'startTimeUtc': '2020-08-15T02:10:24.629832Z', 'endTimeUtc': '2020-08-15T02:13:01.288464Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4be35fe3-78d0-40f7-993c-68d25407b1c3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '6711c624-86ad-47c9-a588-76ff083bb609', 'azureml.pipelinerunid': '2c0aacff-454a-4c60-9207-1c7b1033168c', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'ae295d27-1d6d-4897-b7d2-d19f9275b922'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'runDefinition': {'script': 'train_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'susumu-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': 'ae295d27-1d6d-4897-b7d2-d19f9275b922', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.11.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_b12824a0eee159365ccfe3146b58a1cd'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.a5614e8d-76f9-4d63-85db-51966e5694fa/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=B7wiIUULeSTIhL7d%2FwNu8kmIZta1VgA56pKqcmhpX44%3D&st=2020-08-15T02%3A02%3A51Z&se=2020-08-15T10%3A12%3A51Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/Exper ...
#
#
#
#
# StepRunId: 2fbefa68-32de-4684-8e14-e5c02c313a0a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/2fbefa68-32de-4684-8e14-e5c02c313a0a?wsid=/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourcegroups/resources/workspaces/workspace
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# ========================================================================================================================
# 2020-08-15T02:15:02Z Starting output-watcher...
# 2020-08-15T02:15:02Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-08-15T02:15:04Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-08-15T02:15:04Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_cff4c801596a77022874525482eac559
# Digest: sha256:e3dd50a3ac13403f60d67e39ba1815b34c737ac4b8d001430f3716b5078ad704
# Status: Image is up to date for 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559:latest
# 6309ea29a083174357bb8ac7e81561b774d6a520ab06a5b59c2061c845e88662
# 2020/08/15 02:15:06 Starting App Insight Logger for task:  containerSetup
# 2020/08/15 02:15:06 Version: 3.0.01307.0006 Branch: master Commit: a589a00
# 2020/08/15 02:15:06 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/15 02:15:06 sshd inside container not required for job, skipping setup.
# 2020/08/15 02:15:07 All App Insights Logs was send successfully
# 2020-08-15T02:15:11Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2020/08/15 02:15:00 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/08/15 02:15:00 Version: 3.0.01307.0006 Branch: master Commit: a589a00
# >>>   2020/08/15 02:15:00 Reading dyanamic configs
# >>>   2020/08/15 02:15:00 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false
# >>>   2020/08/15 02:15:00 DetonationChamber is not enabled on this subscription: 84170def-2683-47c0-91ed-1f34057afd69
# >>>   2020/08/15 02:15:00 GPU count found: 0
# >>>   2020/08/15 02:15:00 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/config
# >>>   2020/08/15 02:15:00 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/08/15 02:15:00 Starting identity responder.
# >>>   2020/08/15 02:15:00 Starting identity responder.
# >>>   2020/08/15 02:15:00 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/08/15 02:15:00 Logfile used for identity responder: /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/2fbefa68-32de-4684-8_cd92507d-327d-4d52-ba5d-984b99a634f4/IdentityResponderLog-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# >>>   2020/08/15 02:15:00 Logfile used for identity responder: /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/2fbefa68-32de-4684-8_cd92507d-327d-4d52-ba5d-984b99a634f4/IdentityResponderLog-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# >>>   2020/08/15 02:15:00 Started Identity Responder for job.
# >>>   2020/08/15 02:15:00 Started Identity Responder for job.
# >>>   2020/08/15 02:15:00 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/wd
# >>>   2020/08/15 02:15:00 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/shared
# >>>   2020/08/15 02:15:00 Mounting job level file systems
# >>>   2020/08/15 02:15:00 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts
# >>>   2020/08/15 02:15:00 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/config/.amlcompute.datastorecredentials
# >>>   2020/08/15 02:15:00 Datastore credentials file not found, skipping.
# >>>   2020/08/15 02:15:00 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/config/.master.runtimesastokens
# >>>   2020/08/15 02:15:00 Runtime sas tokens file not found, skipping.
# >>>   2020/08/15 02:15:00 No NFS configured
# >>>   2020/08/15 02:15:00 No Azure File Shares configured
# >>>   2020/08/15 02:15:00 Mounting blob file systems
# >>>   2020/08/15 02:15:00 Mounting azureml-blobstore-9c7fb7c2-411f-4b22-b0f8-9a8ab7233042 container from workspace9901294163 account at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore
# >>>   2020/08/15 02:15:00 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 02:15:00 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 02:15:00 Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 02:15:00 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore
# >>>   2020/08/15 02:15:00 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore
# >>>   2020/08/15 02:15:00 Successfully mounted azureml-blobstore-9c7fb7c2-411f-4b22-b0f8-9a8ab7233042 container from workspace9901294163 account at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore
# >>>   2020/08/15 02:15:00 No unmanaged file systems configured
# >>>   2020/08/15 02:15:00 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/azureml_compute_logs
# >>>   2020/08/15 02:15:02 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/logs
# >>>   2020/08/15 02:15:02 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/outputs
# >>>   2020/08/15 02:15:02 Starting output-watcher...
# >>>   2020/08/15 02:15:03 Start to pulling docker image: 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559
# >>>   2020/08/15 02:15:03 Requesting XDS for registry details.
# >>>   2020/08/15 02:15:03 Attempt 1 of http call to https://cq1-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourceGroups/resources/workspaces/workspace/clusters/susumu-cluster/nodes/tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d?api-version=2018-02-01
# >>>   2020/08/15 02:15:04 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/08/15 02:15:04 Got container registry details from credentials service.
# >>>   2020/08/15 02:15:04 Writing ACR Details to file...
# >>>   2020/08/15 02:15:04 Copying ACR Details file to worker nodes...
# >>>   2020/08/15 02:15:04 Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2020/08/15 02:15:04 Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/08/15 02:15:05 Pull docker image time: 2.257848256s
# >>>
# >>>   2020/08/15 02:15:05 Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/08/15 02:15:05 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# ...
# >>>   2020/08/15 02:15:07 Container ssh is not required for job type.
# >>>   2020/08/15 02:15:07 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/azureml_compute_logs
# >>>   2020/08/15 02:15:07 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python $AZ_BATCHAI_INPUT_AZUREML/2fbefa68-32de-4684-8e14-e5c02c313a0a-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 02:15:07 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/azureml_compute_logs/65_job_prep-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# >>>   2020/08/15 02:15:07 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/azureml_compute_logs/65_job_prep-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# >>>   2020/08/15 02:15:07 native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a;/azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 02:15:07 runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t 2fbefa68-32de-4684-8e14-e5c02c313a0a bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a;/azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a/mounts/workspaceblobstore/azureml/2fbefa68-32de-4684-8e14-e5c02c313a0a-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 02:15:11 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.159887] Entering job preparation.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.728622] TimeoutHandler __init__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.728679] TimeoutHandler __enter__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.730593] Starting job preparation.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.730635] Extracting the control code.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.762790] fetching and extracting the control code on master node.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.762850] Starting extract_project.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:08.762920] Starting to extract zip file.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:09.622427] Finished extracting zip file.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:09.788544] Using urllib.request Python 3.0 or later
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:09.788649] Start fetching snapshots.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:09.788698] Start fetching snapshot.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:09.788716] Retrieving project from snapshot: 4be35fe3-78d0-40f7-993c-68d25407b1c3
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 51
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:09.789858] Start RetrieveProjectSasUrls
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.111301] Finished RetrieveProjectSasUrls
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.111347] TimeoutHandler __init__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.111363] TimeoutHandler __enter__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.120092] TimeoutHandler __exit__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.120138] Starting project file download.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.120189] Starting _download_tree for file.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.120270] _download_tree start request for file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.138677] _download_tree finished request for file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.138704] _download_tree start writing file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.138715] TimeoutHandler __init__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.138728] TimeoutHandler __enter__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.201562] TimeoutHandler __exit__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.201609] _download_tree finished writing file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.201648] Starting _download_tree for file.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.201751] _download_tree start request for file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.219480] _download_tree finished request for file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.219510] _download_tree start writing file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.219527] TimeoutHandler __init__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.219540] TimeoutHandler __enter__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.284446] TimeoutHandler __exit__
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.284530] _download_tree finished writing file
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.284626] Finished project file download.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.284673] Finished fetching snapshot.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.284694] Finished fetching snapshots.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.284713] Finished extract_project.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.304341] Finished fetching and extracting the control code.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.308382] Start run_history_prep.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.308668] downloadDataStore - Download from datastores if requested.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:10.360054] Entering context manager injector.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: Acquired lockfile /tmp/2fbefa68-32de-4684-8e14-e5c02c313a0a-datastore.lock to downloading input data references
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:11.575692] downloadDataStore completed
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:11.581019] Job preparation is complete.
# >>>   2020/08/15 02:15:11 runSpecialJobTask: preparation: [2020-08-15T02:15:11.581332] TimeoutHandler __exit__
# >>>   2020/08/15 02:15:11 All App Insights Logs was send successfully
# >>>   2020/08/15 02:15:11 Process Exiting with Code:  0
# >>>
# 2020-08-15T02:15:12Z 127.0.0.1 slots=2 max-slots=2
# 2020-08-15T02:15:12Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-15T02:15:19.590730
# Starting job release. Current time:2020-08-15T02:15:20.528033
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 140
# [2020-08-15T02:15:20.547428] Entering context manager injector.
# Job release is complete. Current time:2020-08-15T02:15:21.033343
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '2fbefa68-32de-4684-8e14-e5c02c313a0a', 'target': 'susumu-cluster', 'status': 'Completed', 'startTimeUtc': '2020-08-15T02:14:57.085406Z', 'endTimeUtc': '2020-08-15T02:15:25.993492Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4be35fe3-78d0-40f7-993c-68d25407b1c3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'ff75aeb0-1b05-4689-8937-b7dbf170db99', 'azureml.pipelinerunid': '2c0aacff-454a-4c60-9207-1c7b1033168c', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'susumu-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a5614e8d-76f9-4d63-85db-51966e5694fa/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.11.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_b12824a0eee159365ccfe3146b58a1cd'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2fbefa68-32de-4684-8e14-e5c02c313a0a/azureml-logs/55_azureml-execution-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt?sv=2019-02-02&sr=b&sig=u6F1HmxFLbetYk7LzYBrtDeJdDzmISxu0XcdNrboD7s%3D&st=2020-08-15T02%3A05%3A22Z&se=2020-08-15T10%3A15%3A22Z&sp=r', 'azureml-logs/65_job_prep-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2fbefa68-32de-4684-8e14-e5c02c313a0a/azureml-logs/65_job_prep-tvmps_36bdb36e76be8751ff56bf59ad082e0a72b802ce1d2de0d7ebba2cb4ac287e42_d.txt?sv=2019-02-02&sr=b&sig=1%2B03frFdyhLKZ27Q%2BrofQhaoYGFp7lNTtTpoU71ELE0%3D&st=2020-08-15T02%3A05%3A22Z&se=2020-08-15T1 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '2c0aacff-454a-4c60-9207-1c7b1033168c', 'status': 'Completed', 'startTimeUtc': '2020-08-15T01:48:34.914516Z', 'endTimeUtc': '2020-08-15T02:15:27.645872Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2c0aacff-454a-4c60-9207-1c7b1033168c/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=JCNSctFFiH03M9XeDRLu8k7jQ5CAxHItK%2BID0Lw5b9s%3D&st=2020-08-15T01%3A38%3A55Z&se=2020-08-15T09%3A48%3A55Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2c0aacff-454a-4c60-9207-1c7b1033168c/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=%2Fxc0IyjQDYqmThqYc%2F%2FFeenYgXvkaJvnSpxz210xhMs%3D&st=2020-08-15T01%3A38%3A55Z&se=2020-08-15T09%3A48%3A55Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2c0aacff-454a-4c60-9207-1c7b1033168c/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=hwmgL511Cz19%2BJ6bWqgmWyQgEL6qILYMK%2Bz0IE4l2q0%3D&st=2020-08-15T01%3A38%3A55Z&se=2020-08-15T09%3A48%3A55Z&sp=r'}}
# 'Finished'

# %% [markdown]
# The widget above shows details of the pipeline as it runs. You can also monitor pipeline runs in the **Experiments** page in [Azure Machine Learning studio](https://ml.azure.com).
#
# > **Note**: If the widget displays the message `["AttributeError: 'NoneType' object has no attribute 'id'\n"]`, you can safely ignore it!
#
# When the pipeline has finished, a new model should be registered with a *Training context* tag indicating it was trained in a pipeline. Run the following code to verify this.

# %%
for model in core.Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# diabetes_model version: 6
# 	 Training context : Pipeline
#
#
# diabetes_model version: 5
# 	 Training context : Parameterized SKLearn Estimator
# 	 AUC : 0.8483904671874223
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 4
# 	 Training context : Parameterized SKLearn Estimator
# 	 AUC : 0.8483904671874223
# 	 Accuracy : 0.7736666666666666
#
#
# diabetes_model version: 3
# 	 Training context : Estimator
# 	 AUC : 0.8484929598487486
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 2
# 	 Training context : Estimator
# 	 AUC : 0.8483377282451863
# 	 Accuracy : 0.774
#
#
# diabetes_model version: 1
# 	 Training context : Estimator
# 	 AUC : 0.8483377282451863
# 	 Accuracy : 0.774

# %% [markdown]
# ## Publish the Pipeline
#
# Now that you've created a pipeline and verified it works, you can publish it as a REST service.

# %%
published_pipeline = p.publish(
    name='Diabetes_Training_Pipeline',
    description="Trains diabetes model",
    version="1.0",
)
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f40ea53b2606> in <module>
# ----> 1 published_pipeline = p.publish(
#       2     name='Diabetes_Training_Pipeline',
#       3     description="Trains diabetes model",
#       4     version="1.0",
#       5 )
#
# NameError: name 'p' is not defined

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. A real application would require a service principal with which to be authenticated, but to test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:

# %%
from azureml.core import authentication

interactive_auth = authentication.InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Now you're ready to call the REST interface. The pipeline runs asynchronously, so you'll get an identifier back, which you can use to track the pipeline experiment as it runs:

# %%
import requests
experiment_name = 'Run-diabetes-pipeline'

response = requests.post(
    rest_endpoint,
    headers=auth_header,
    json={"ExperimentName": experiment_name},
)
run_id = response.json()["Id"]
run_id

# %% [markdown]
# Since you have the run ID, you can use the **RunDetails** widget to view the experiment as it runs.
#
# > **Note**: The pipeline should complete quickly, because each step was configured to allow output reuse. This was done primarily for convenience and to save time in this example. In reality, you'd likely want the first step to run every time in case the data has changed, and trigger the subsequent steps only if the output from step one changes.
# >
# > The widget may not refresh quickly enough to indicate that the pipeline run has completed - keep an eye on the kernel indicator at the top right of the page, when it turns from ⚫ to ◯, the code has finished running.

# %%
published_pipeline_run = pipeline.core.run.PipelineRun(
    ws.experiments[experiment_name], run_id
)
widgets.RunDetails(published_pipeline_run).show()
pipeline_run.wait_for_completion()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7?wsid=/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourcegroups/resources/workspaces/workspace
# PipelineRun Status: Running
#
#
# StepRunId: 71d4e115-0b79-401a-b118-aac833f50006
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/71d4e115-0b79-401a-b118-aac833f50006?wsid=/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourcegroups/resources/workspaces/workspace
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# ========================================================================================================================
# 2020-08-15T04:41:01Z Starting output-watcher...
# 2020-08-15T04:41:01Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-08-15T04:41:02Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-08-15T04:41:02Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_cff4c801596a77022874525482eac559
# Digest: sha256:e3dd50a3ac13403f60d67e39ba1815b34c737ac4b8d001430f3716b5078ad704
# Status: Image is up to date for 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559:latest
# 9d1fd7e2c665dc9e046690554eb46d288bcdc5c73dd88ff7f5ba6afacdfd7163
# 2020/08/15 04:41:04 Starting App Insight Logger for task:  containerSetup
# 2020/08/15 04:41:04 Version: 3.0.01307.0006 Branch: master Commit: a589a00
# 2020/08/15 04:41:04 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/15 04:41:04 sshd inside container not required for job, skipping setup.
# 2020/08/15 04:41:04 All App Insights Logs was send successfully
# 2020-08-15T04:41:10Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2020/08/15 04:40:58 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/08/15 04:40:58 Version: 3.0.01307.0006 Branch: master Commit: a589a00
# >>>   2020/08/15 04:40:58 Reading dyanamic configs
# >>>   2020/08/15 04:40:58 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false
# >>>   2020/08/15 04:40:58 DetonationChamber is not enabled on this subscription: 84170def-2683-47c0-91ed-1f34057afd69
# >>>   2020/08/15 04:40:58 GPU count found: 0
# >>>   2020/08/15 04:40:58 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/config
# >>>   2020/08/15 04:40:58 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/08/15 04:40:58 Starting identity responder.
# >>>   2020/08/15 04:40:58 Starting identity responder.
# >>>   2020/08/15 04:40:58 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/08/15 04:40:58 Logfile used for identity responder: /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/71d4e115-0b79-401a-b_3fc62817-c1d2-4e1f-a821-69d554a91503/IdentityResponderLog-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:40:58 Logfile used for identity responder: /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/71d4e115-0b79-401a-b_3fc62817-c1d2-4e1f-a821-69d554a91503/IdentityResponderLog-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:40:58 Started Identity Responder for job.
# >>>   2020/08/15 04:40:58 Started Identity Responder for job.
# >>>   2020/08/15 04:40:58 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/wd
# >>>   2020/08/15 04:40:58 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/shared
# >>>   2020/08/15 04:40:58 Mounting job level file systems
# >>>   2020/08/15 04:40:58 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts
# >>>   2020/08/15 04:40:58 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/config/.amlcompute.datastorecredentials
# >>>   2020/08/15 04:40:58 Datastore credentials file not found, skipping.
# >>>   2020/08/15 04:40:58 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/config/.master.runtimesastokens
# >>>   2020/08/15 04:40:58 Runtime sas tokens file not found, skipping.
# >>>   2020/08/15 04:40:58 No NFS configured
# >>>   2020/08/15 04:40:58 No Azure File Shares configured
# >>>   2020/08/15 04:40:58 Mounting blob file systems
# >>>   2020/08/15 04:40:58 Mounting azureml-blobstore-9c7fb7c2-411f-4b22-b0f8-9a8ab7233042 container from workspace9901294163 account at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore
# >>>   2020/08/15 04:40:58 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 04:40:58 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 04:40:58 Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 04:40:59 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore
# >>>   2020/08/15 04:40:59 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore
# >>>   2020/08/15 04:40:59 Successfully mounted azureml-blobstore-9c7fb7c2-411f-4b22-b0f8-9a8ab7233042 container from workspace9901294163 account at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore
# >>>   2020/08/15 04:40:59 No unmanaged file systems configured
# >>>   2020/08/15 04:40:59 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/azureml_compute_logs
# >>>   2020/08/15 04:41:01 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/logs
# >>>   2020/08/15 04:41:01 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/outputs
# >>>   2020/08/15 04:41:01 Starting output-watcher...
# >>>   2020/08/15 04:41:02 Start to pulling docker image: 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559
# >>>   2020/08/15 04:41:02 Requesting XDS for registry details.
# >>>   2020/08/15 04:41:02 Attempt 1 of http call to https://cq1-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourceGroups/resources/workspaces/workspace/clusters/susumu-cluster/nodes/tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d?api-version=2018-02-01
# >>>   2020/08/15 04:41:02 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/08/15 04:41:02 Got container registry details from credentials service.
# >>>   2020/08/15 04:41:02 Writing ACR Details to file...
# >>>   2020/08/15 04:41:02 Copying ACR Details file to worker nodes...
# >>>   2020/08/15 04:41:02 Executing 'Copy ACR Details file' on 10.0.0.5
# >>>   2020/08/15 04:41:02 Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/08/15 04:41:03 Pull docker image time: 1.36104933s
# >>>
# >>>   2020/08/15 04:41:03 Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/08/15 04:41:03 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/08/15 04:41:03 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 71d4e115-0b79-401a-b118-aac833f50006 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/71d4e115-0b79-401a-b_3fc62817-c1d2-4e1f-a821-69d554a91503/certs:/mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/71d4e115-0b79-401a-b_3fc62817-c1d2-4e1f-a821-69d554a91503/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006:/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006 -v /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/71d4e115-0b79-401a-b_3fc62817-c1d2-4e1f-a821-69d554a91503/wd:/mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/71d4e115-0b79-401a-b_3fc62817-c1d2-4e1f-a821-69d554a91503/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559
# >>>   2020/08/15 04:41:05 Container ssh is not required for job type.
# >>>   2020/08/15 04:41:05 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/azureml_compute_logs
# >>>   2020/08/15 04:41:05 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python $AZ_BATCHAI_INPUT_AZUREML/71d4e115-0b79-401a-b118-aac833f50006-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 04:41:05 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/azureml_compute_logs/65_job_prep-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:41:05 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/azureml_compute_logs/65_job_prep-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:41:05 native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006;/azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 04:41:05 runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t 71d4e115-0b79-401a-b118-aac833f50006 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006;/azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 04:41:09 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.019045] Entering job preparation.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.820170] TimeoutHandler __init__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.820214] TimeoutHandler __enter__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.821429] Starting job preparation.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.821462] Extracting the control code.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.862290] fetching and extracting the control code on master node.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.862336] Starting extract_project.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:06.862377] Starting to extract zip file.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:07.732014] Finished extracting zip file.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:07.913443] Using urllib.request Python 3.0 or later
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:07.913534] Start fetching snapshots.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:07.913588] Start fetching snapshot.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:07.913606] Retrieving project from snapshot: 4be35fe3-78d0-40f7-993c-68d25407b1c3
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 51
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:07.914602] Start RetrieveProjectSasUrls
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.290987] Finished RetrieveProjectSasUrls
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.291055] TimeoutHandler __init__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.291067] TimeoutHandler __enter__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.292308] TimeoutHandler __exit__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.292339] Starting project file download.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.292387] Starting _download_tree for file.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.292465] _download_tree start request for file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.313250] _download_tree finished request for file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.313313] _download_tree start writing file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.313323] TimeoutHandler __init__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.313347] TimeoutHandler __enter__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.383873] TimeoutHandler __exit__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.383960] _download_tree finished writing file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.384018] Starting _download_tree for file.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.384152] _download_tree start request for file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.408004] _download_tree finished request for file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.408031] _download_tree start writing file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.408049] TimeoutHandler __init__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.408072] TimeoutHandler __enter__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.476700] TimeoutHandler __exit__
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.476753] _download_tree finished writing file
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.476789] Finished project file download.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.476833] Finished fetching snapshot.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.476846] Finished fetching snapshots.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.476856] Finished extract_project.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.494932] Finished fetching and extracting the control code.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.498942] Start run_history_prep.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.499029] downloadDataStore - Download from datastores if requested.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:08.560561] Entering context manager injector.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: Acquired lockfile /tmp/71d4e115-0b79-401a-b118-aac833f50006-datastore.lock to downloading input data references
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:09.869192] downloadDataStore completed
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:09.872656] Job preparation is complete.
# >>>   2020/08/15 04:41:09 runSpecialJobTask: preparation: [2020-08-15T04:41:09.872805] TimeoutHandler __exit__
# >>>   2020/08/15 04:41:10 All App Insights Logs was send successfully
# >>>   2020/08/15 04:41:10 Process Exiting with Code:  0
# >>>
# 2020-08-15T04:41:10Z 127.0.0.1 slots=2 max-slots=2
# 2020-08-15T04:41:10Z launching Custom job
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# [2020-08-15T04:41:11.316314] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['train_diabetes.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/model_folder'])
# Starting the daemon thread to refresh tokens in background for process with pid = 109
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006
# Preparing to call script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/model_folder']
# After variable expansion, calling script [ train_diabetes.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/71d4e115-0b79-401a-b118-aac833f50006/mounts/workspaceblobstore/azureml/71d4e115-0b79-401a-b118-aac833f50006/model_folder']
#
# Script type = None
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8986666666666666
# AUC: 0.8840825658444825
# Starting the daemon thread to refresh tokens in background for process with pid = 109
#
#
# The experiment completed successfully. Finalizing run...
# [2020-08-15T04:41:32.027823] TimeoutHandler __init__
# [2020-08-15T04:41:32.027895] TimeoutHandler __enter__
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.14618396759033203 seconds
# [2020-08-15T04:41:32.245670] TimeoutHandler __exit__
# 2020/08/15 04:41:33 Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-15T04:41:34.440557
# Starting job release. Current time:2020-08-15T04:41:35.520965
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 319
# [2020-08-15T04:41:35.541587] Entering context manager injector.
# Job release is complete. Current time:2020-08-15T04:41:36.060014
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': '71d4e115-0b79-401a-b118-aac833f50006', 'target': 'susumu-cluster', 'status': 'Completed', 'startTimeUtc': '2020-08-15T04:41:00.021252Z', 'endTimeUtc': '2020-08-15T04:41:42.677226Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4be35fe3-78d0-40f7-993c-68d25407b1c3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '332f461c-1e28-44b8-aadc-e57728e886ee', 'azureml.pipelinerunid': '2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'ae295d27-1d6d-4897-b7d2-d19f9275b922'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_train', 'mechanism': 'Direct'}}], 'runDefinition': {'script': 'train_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'susumu-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/71d4e115-0b79-401a-b118-aac833f50006/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'diabetes_train': {'dataLocation': {'dataset': {'id': 'ae295d27-1d6d-4897-b7d2-d19f9275b922', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'diabetes_train', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.11.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_b12824a0eee159365ccfe3146b58a1cd'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.71d4e115-0b79-401a-b118-aac833f50006/azureml-logs/55_azureml-execution-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt?sv=2019-02-02&sr=b&sig=UR9YUDX7rYdBZUdY2OfCr%2FXv5QGApk0AuTDz79F8i4Y%3D&st=2020-08-15T04%3A31%3A38Z&se=2020-08-15T12%3A41%3A38Z&sp=r', 'azureml-logs/65_job_prep-tv ...
#
#
#
#
# StepRunId: c7d07c4a-4c61-44af-952f-0d5d5da6af39
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-training-pipeline/runs/c7d07c4a-4c61-44af-952f-0d5d5da6af39?wsid=/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourcegroups/resources/workspaces/workspace
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# ========================================================================================================================
# 2020-08-15T04:41:53Z Starting output-watcher...
# 2020-08-15T04:41:53Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-08-15T04:41:54Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-08-15T04:41:54Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_cff4c801596a77022874525482eac559
# Digest: sha256:e3dd50a3ac13403f60d67e39ba1815b34c737ac4b8d001430f3716b5078ad704
# Status: Image is up to date for 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559:latest
# 70fc9c338ce3e157737ff9ba1479a64fa7c98c6fe701de8f92df7cd5466894d0
# 2020/08/15 04:41:56 Starting App Insight Logger for task:  containerSetup
# 2020/08/15 04:41:56 Version: 3.0.01307.0006 Branch: master Commit: a589a00
# 2020/08/15 04:41:56 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/08/15 04:41:56 sshd inside container not required for job, skipping setup.
# 2020/08/15 04:41:57 All App Insights Logs was send successfully
# 2020-08-15T04:42:02Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2020/08/15 04:41:50 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/08/15 04:41:50 Version: 3.0.01307.0006 Branch: master Commit: a589a00
# >>>   2020/08/15 04:41:50 Reading dyanamic configs
# >>>   2020/08/15 04:41:50 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false
# >>>   2020/08/15 04:41:50 DetonationChamber is not enabled on this subscription: 84170def-2683-47c0-91ed-1f34057afd69
# >>>   2020/08/15 04:41:50 GPU count found: 0
# >>>   2020/08/15 04:41:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/config
# >>>   2020/08/15 04:41:50 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/08/15 04:41:50 Starting identity responder.
# >>>   2020/08/15 04:41:50 Starting identity responder.
# >>>   2020/08/15 04:41:50 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/08/15 04:41:50 Logfile used for identity responder: /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/c7d07c4a-4c61-44af-9_fe4403ba-0117-4c16-9d46-1093e810e200/IdentityResponderLog-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:41:50 Logfile used for identity responder: /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/c7d07c4a-4c61-44af-9_fe4403ba-0117-4c16-9d46-1093e810e200/IdentityResponderLog-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:41:50 Started Identity Responder for job.
# >>>   2020/08/15 04:41:50 Started Identity Responder for job.
# >>>   2020/08/15 04:41:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/wd
# >>>   2020/08/15 04:41:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/shared
# >>>   2020/08/15 04:41:50 Mounting job level file systems
# >>>   2020/08/15 04:41:50 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts
# >>>   2020/08/15 04:41:50 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/config/.amlcompute.datastorecredentials
# >>>   2020/08/15 04:41:50 Datastore credentials file not found, skipping.
# >>>   2020/08/15 04:41:50 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/config/.master.runtimesastokens
# >>>   2020/08/15 04:41:50 Runtime sas tokens file not found, skipping.
# >>>   2020/08/15 04:41:50 No NFS configured
# >>>   2020/08/15 04:41:50 No Azure File Shares configured
# >>>   2020/08/15 04:41:50 Mounting blob file systems
# >>>   2020/08/15 04:41:50 Mounting azureml-blobstore-9c7fb7c2-411f-4b22-b0f8-9a8ab7233042 container from workspace9901294163 account at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore
# >>>   2020/08/15 04:41:50 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 04:41:50 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/08/15 04:41:50 Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 04:41:50 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore
# >>>   2020/08/15 04:41:50 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore
# >>>   2020/08/15 04:41:51 Successfully mounted azureml-blobstore-9c7fb7c2-411f-4b22-b0f8-9a8ab7233042 container from workspace9901294163 account at /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore
# >>>   2020/08/15 04:41:51 No unmanaged file systems configured
# >>>   2020/08/15 04:41:51 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml_compute_logs
# >>>   2020/08/15 04:41:53 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/logs
# >>>   2020/08/15 04:41:53 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/outputs
# >>>   2020/08/15 04:41:53 Starting output-watcher...
# >>>   2020/08/15 04:41:53 Start to pulling docker image: 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559
# >>>   2020/08/15 04:41:53 Requesting XDS for registry details.
# >>>   2020/08/15 04:41:53 Attempt 1 of http call to https://cq1-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/84170def-2683-47c0-91ed-1f34057afd69/resourceGroups/resources/workspaces/workspace/clusters/susumu-cluster/nodes/tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d?api-version=2018-02-01
# >>>   2020/08/15 04:41:54 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/08/15 04:41:54 Got container registry details from credentials service.
# >>>   2020/08/15 04:41:54 Writing ACR Details to file...
# >>>   2020/08/15 04:41:54 Copying ACR Details file to worker nodes...
# >>>   2020/08/15 04:41:54 Executing 'Copy ACR Details file' on 10.0.0.5
# >>>   2020/08/15 04:41:54 Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/08/15 04:41:55 Pull docker image time: 1.359979052s
# >>>
# >>>   2020/08/15 04:41:55 Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/08/15 04:41:55 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/08/15 04:41:55 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name c7d07c4a-4c61-44af-952f-0d5d5da6af39 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/c7d07c4a-4c61-44af-9_fe4403ba-0117-4c16-9d46-1093e810e200/certs:/mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/c7d07c4a-4c61-44af-9_fe4403ba-0117-4c16-9d46-1093e810e200/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39:/mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39 -v /mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/c7d07c4a-4c61-44af-9_fe4403ba-0117-4c16-9d46-1093e810e200/wd:/mnt/batch/tasks/workitems/fe52c270-5882-484d-a5e4-2145cbcb91a3/job-1/c7d07c4a-4c61-44af-9_fe4403ba-0117-4c16-9d46-1093e810e200/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host 9c7fb7c2411f4b22b0f89a8ab7233042.azurecr.io/azureml/azureml_cff4c801596a77022874525482eac559
# >>>   2020/08/15 04:41:57 Container ssh is not required for job type.
# >>>   2020/08/15 04:41:57 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml_compute_logs
# >>>   2020/08/15 04:41:57 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python $AZ_BATCHAI_INPUT_AZUREML/c7d07c4a-4c61-44af-952f-0d5d5da6af39-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 04:41:57 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml_compute_logs/65_job_prep-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:41:57 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml_compute_logs/65_job_prep-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# >>>   2020/08/15 04:41:57 native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39;/azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/08/15 04:41:57 runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t c7d07c4a-4c61-44af-952f-0d5d5da6af39 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39;/azureml-envs/azureml_b12824a0eee159365ccfe3146b58a1cd/bin/python /mnt/batch/tasks/shared/LS_root/jobs/workspace/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39/mounts/workspaceblobstore/azureml/c7d07c4a-4c61-44af-952f-0d5d5da6af39-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4be35fe3-78d0-40f7-993c-68d25407b1c3","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/08/15 04:42:02 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:58.206514] Entering job preparation.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.035021] TimeoutHandler __init__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.035073] TimeoutHandler __enter__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.036542] Starting job preparation.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.036569] Extracting the control code.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.072164] fetching and extracting the control code on master node.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.072214] Starting extract_project.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.072274] Starting to extract zip file.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:41:59.987342] Finished extracting zip file.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.175028] Using urllib.request Python 3.0 or later
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.175134] Start fetching snapshots.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.175179] Start fetching snapshot.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.175197] Retrieving project from snapshot: 4be35fe3-78d0-40f7-993c-68d25407b1c3
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 52
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.176233] Start RetrieveProjectSasUrls
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.709107] Finished RetrieveProjectSasUrls
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.709155] TimeoutHandler __init__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.709167] TimeoutHandler __enter__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.710380] TimeoutHandler __exit__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.710413] Starting project file download.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.710460] Starting _download_tree for file.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.710537] _download_tree start request for file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.856607] _download_tree finished request for file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.856638] _download_tree start writing file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.856649] TimeoutHandler __init__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.856659] TimeoutHandler __enter__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.924424] TimeoutHandler __exit__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.924476] _download_tree finished writing file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.924519] Starting _download_tree for file.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.924670] _download_tree start request for file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.949200] _download_tree finished request for file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.949248] _download_tree start writing file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.949260] TimeoutHandler __init__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:00.949269] TimeoutHandler __enter__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.014705] TimeoutHandler __exit__
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.014782] _download_tree finished writing file
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.014834] Finished project file download.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.014896] Finished fetching snapshot.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.014908] Finished fetching snapshots.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.014918] Finished extract_project.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.031839] Finished fetching and extracting the control code.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.035547] Start run_history_prep.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.035588] downloadDataStore - Download from datastores if requested.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:01.099819] Entering context manager injector.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: Acquired lockfile /tmp/c7d07c4a-4c61-44af-952f-0d5d5da6af39-datastore.lock to downloading input data references
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:02.358078] downloadDataStore completed
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:02.361718] Job preparation is complete.
# >>>   2020/08/15 04:42:02 runSpecialJobTask: preparation: [2020-08-15T04:42:02.362093] TimeoutHandler __exit__
# >>>   2020/08/15 04:42:02 All App Insights Logs was send successfully
# >>>   2020/08/15 04:42:02 Process Exiting with Code:  0
# >>>
# 2020-08-15T04:42:02Z 127.0.0.1 slots=2 max-slots=2
# 2020-08-15T04:42:03Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-08-15T04:42:10.149791
# Starting job release. Current time:2020-08-15T04:42:11.248473
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 141
# [2020-08-15T04:42:11.270081] Entering context manager injector.
# Job release is complete. Current time:2020-08-15T04:42:11.788875
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': 'c7d07c4a-4c61-44af-952f-0d5d5da6af39', 'target': 'susumu-cluster', 'status': 'Completed', 'startTimeUtc': '2020-08-15T04:41:55.867956Z', 'endTimeUtc': '2020-08-15T04:42:16.761418Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4be35fe3-78d0-40f7-993c-68d25407b1c3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '4791068b-fcf4-4741-a74c-4bcfaee7d6c9', 'azureml.pipelinerunid': '2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'register_diabetes.py', 'scriptType': None, 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'susumu-cluster', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/71d4e115-0b79-401a-b118-aac833f50006/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'diabetes-pipeline-env', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.11.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'pandas'], 'name': 'azureml_b12824a0eee159365ccfe3146b58a1cd'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200723.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'cmAksCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml-logs/55_azureml-execution-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt?sv=2019-02-02&sr=b&sig=BFwYAnGhNtz%2BETCOCGV64J7oK%2B%2F5J9KPWR0KWh2geSo%3D&st=2020-08-15T04%3A32%3A13Z&se=2020-08-15T12%3A42%3A13Z&sp=r', 'azureml-logs/65_job_prep-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.c7d07c4a-4c61-44af-952f-0d5d5da6af39/azureml-logs/65_job_prep-tvmps_cbfa9779474cbd4d1fe8a7638e2386fd47909b8a0e97daa72edfe25375ed2a90_d.txt?sv=2019-02-02&sr=b&sig=5eZwH1E1JEYHCAEMMFHtGUwF5yQvtEqzj%2BXH0A%2B98ZM%3D&st=2020-08-15T04%3A32%3A13Z&se=2020-0 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7', 'status': 'Completed', 'startTimeUtc': '2020-08-15T04:40:44.432811Z', 'endTimeUtc': '2020-08-15T04:42:17.767365Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=jBLSIUx10ygk7Io1H3qOUOpSrX105PJZiCtbBfLVAMk%3D&st=2020-08-15T04%3A32%3A18Z&se=2020-08-15T12%3A42%3A18Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=YEcaZ6qw2ud8We7lso8YwGX6P2RrF51hr3qAuFiT9U0%3D&st=2020-08-15T04%3A32%3A18Z&se=2020-08-15T12%3A42%3A18Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://workspace9901294163.blob.core.windows.net/azureml/ExperimentRun/dcid.2b6d4f14-ee5a-4f8e-b94c-5f9bb94ee2a7/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=9su1xX8bihUp8yV%2BxotP39%2FwG5ESL%2FJoEXT8s%2FoQHh4%3D&st=2020-08-15T04%3A32%3A18Z&se=2020-08-15T12%3A42%3A18Z&sp=r'}}
# 'Finished'

# %% [markdown]
# This is a simple example, designed to demonstrate the principle. In reality, you could build more sophisticated logic into the pipeline steps - for example, evaluating the model against some test data to calculate a performance metric like AUC or accuracy, comparing the metric to that of any previously registered versions of the model, and only registering the new model if it performs better.
#
# You can use the [Azure Machine Learning extension for Azure DevOps](https://marketplace.visualstudio.com/items?itemName=ms-air-aiagility.vss-services-azureml) to combine Azure ML pipelines with Azure DevOps pipelines (yes, it *is* confusing that they have the same name!) and integrate model retraining into a *continuous integration/continuous deployment (CI/CD)* process. For example you could use an Azure DevOps *build* pipeline to trigger an Azure ML pipeline that trains and registers a model, and when the model is registered it could trigger an Azure Devops *release* pipeline that deploys the model as a web service, along with the application or service that consumes the model.
